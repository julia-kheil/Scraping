# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.9 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import app, reviews, Sort, reviews_all

# %% [markdown]
# https://play.google.com/store/apps/details?id=com.natusi.sicantik&hl=en-us
#
# https://play.google.com/store/apps/details?id=co.id.natusi.sikda&hl=en-us

# %%
scrapreview=reviews_all(
    'co.id.natusi.sikda',
    lang='id',
    sort=Sort.MOST_RELEVANT
)

# %%
import pandas as pd
df_reviews = pd.DataFrame(scrapreview)

df_reviews.head()
# Out:
#                                reviewId               userName  \
# 0  4b326d10-b2c2-4a10-9f81-f7da44a3da03  Yohana Endang Sunarwo
# 1  c6a8a609-6373-4c93-bcd6-a1b26863775a             Widah Yati
# 2  48f924a3-0e51-44f9-9f03-4ec938d5a20b            Avena Stuff
# 3  3355da89-56b3-4943-9184-327af62e4162        Dinar Provianti
# 4  aad5b277-b722-443d-abfc-481ca17e413c          Roihatul Ilmi
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  Aplikasi ga jelas. Baca ulasan emang bener sem...      1              3
# 1  Aplikasi tidak berguna sesuai fungsinya. Sudah...      1              1
# ...

# %%
# !pip install wordcloud matplotlib

# %%
from wordcloud import   WordCloud
import matplotlib.pyplot as plt

text = ''. join(df_reviews['content'].astype(str))

wordcloud = WordCloud(width=800, height=400, background_color='white',max_words=200).generate(text)

plt.figure(figsize=(20, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
